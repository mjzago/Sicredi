# %%
pip install deep-translator
# Out:
# Collecting deep-translator
#   Downloading deep_translator-1.11.4-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in c:\users\mjzag\appdata\local\programs\python\python311\lib\site-packages (from deep-translator) (4.12.2)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in c:\users\mjzag\appdata\local\programs\python\python311\lib\site-packages (from deep-translator) (2.31.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\mjzag\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mjzag\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mjzag\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mjzag\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mjzag\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2023.7.22)
# Downloading deep_translator-1.11.4-py3-none-any.whl (42 kB)
#    ---------------------------------------- 0.0/42.3 kB ? eta -:--:--
#    ---------------------------------------- 42.3/42.3 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: deep-translator
# Successfully installed deep-translator-1.11.4
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os

# Diretórios de entrada e saída
diretorio_entrada = 'data/nlp'
diretorio_saida_normalizado = 'data/nlp_normalized'

# Percorrer arquivos de texto no diretório de entrada
for pasta_raiz, _, arquivos in os.walk(diretorio_entrada):
    for arquivo in arquivos:
        if arquivo.endswith('.txt'):
            caminho_completo_entrada = os.path.join(pasta_raiz, arquivo)
            caminho_completo_saida = os.path.join(pasta_raiz.replace(diretorio_entrada, diretorio_saida_normalizado), arquivo)

            # Verificar se o arquivo já foi normalizado
            if os.path.exists(caminho_completo_saida):
                print(f"O arquivo '{arquivo}' já foi normalizado. Pulando para o próximo arquivo.")
                continue

            print(f"Normalizando arquivo: {caminho_completo_entrada}")

            # Ler o conteúdo do arquivo de entrada
            with open(caminho_completo_entrada, 'r', encoding='utf-8') as arquivo_entrada:
                texto = arquivo_entrada.read()

            # Remover quebras de linha e normalizar o texto
            texto_normalizado = texto.replace('\n', ' ')

            # Criar diretório de saída se não existir
            os.makedirs(os.path.dirname(caminho_completo_saida), exist_ok=True)

            # Escrever o texto normalizado no arquivo de saída
            with open(caminho_completo_saida, 'w', encoding='utf-8') as arquivo_saida:
                arquivo_saida.write(texto_normalizado)

            print(f"Arquivo '{arquivo}' normalizado e salvo em: {caminho_completo_saida}")
# Out:
# Normalizando arquivo: data/nlp\CC SICREDI COOMAMP\ago-age_de_04042023_-_sicredi_coomamp.txt
# Arquivo 'ago-age_de_04042023_-_sicredi_coomamp.txt' normalizado e salvo em: data/nlp_normalized\CC SICREDI COOMAMP\ago-age_de_04042023_-_sicredi_coomamp.txt
# Normalizando arquivo: data/nlp\CC SICREDI COOMAMP\ata_age_digital_2020-10906245163955933242.txt
# Arquivo 'ata_age_digital_2020-10906245163955933242.txt' normalizado e salvo em: data/nlp_normalized\CC SICREDI COOMAMP\ata_age_digital_2020-10906245163955933242.txt
# Normalizando arquivo: data/nlp\CC SICREDI COOMAMP\ata_ago-age_2020_-_sicredi_coomamp-14269571789062083743.txt
# Arquivo 'ata_ago-age_2020_-_sicredi_coomamp-14269571789062083743.txt' normalizado e salvo em: data/nlp_normalized\CC SICREDI COOMAMP\ata_ago-age_2020_-_sicredi_coomamp-14269571789062083743.txt
# Normalizando arquivo: data/nlp\CC SICREDI COOMAMP\ata_agoage_2022_-_sicredi_coomamp.txt
# Arquivo 'ata_agoage_2022_-_sicredi_coomamp.txt' normalizado e salvo em: data/nlp_normalized\CC SICREDI COOMAMP\ata_agoage_2022_-_sicredi_coomamp.txt
# Normalizando arquivo: data/nlp\CC SICREDI COOMAMP\ata_ago_age_2018-5498222428478009411.txt
# Arquivo 'ata_ago_age_2018-5498222428478009411.txt' normalizado e salvo em: data/nlp_normalized\CC SICREDI COOMAMP\ata_ago_age_2018-5498222428478009411.txt
# Normalizando arquivo: data/nlp\CC SICREDI COOMAMP\ata_de_homologacao-2409316498742798561.txt
# Arquivo 'ata_de_homologacao-2409316498742798561.txt' normalizado e salvo em: data/nlp_normalized\CC SICREDI COOMAMP\ata_de_homologacao-2409316498742798561.txt
# Normalizando arquivo: data/nlp\CC SICREDI COOMAMP\chapas_inscritas-7992939441822030231.txt
# Arquivo 'chapas_inscritas-7992939441822030231.txt' normalizado e salvo em: data/nlp_normalized\CC SICREDI COOMAMP\chapas_inscritas-7992939441822030231.txt
# Normalizando arquivo: data/nlp\CC SICREDI COOMAMP\edital-de-convocacao-ago-age-2020-9922671639141617290.txt
# Arquivo 'edital-de-convocacao-ago-age-2020-9922671639141617290.txt' normalizado e salvo em: data/nlp_normalized\CC SICREDI COOMAMP\edital-de-convocacao-ago-age-2020-9922671639141617290.txt
# Normalizando arquivo: data/nlp\CC SICREDI COOMAMP\edital_age__presencial_maio2023.txt
# Arquivo 'edital_age__presencial_maio2023.txt' normalizado e salvo em: data/nlp_normalized\CC SICREDI COOMAMP\edital_age__presencial_maio2023.txt
# Normalizando arquivo: data/nlp\CC SICREDI COOMAMP\edital_ago-age_-_2022-5192814098258424985.txt
# Arquivo 'edital_ago-age_-_2022-5192814098258424985.txt' normalizado e salvo em: data/nlp_normalized\CC SICREDI COOMAMP\edital_ago-age_-_2022-5192814098258424985.txt
# Normalizando arquivo: data/nlp\CC SICREDI COOMAMP\edital_agoage__virtual_2023.txt
# Arquivo 'edital_agoage__virtual_2023.txt' normalizado e salvo em: data/nlp_normalized\CC SICREDI COOMAMP\edital_agoage__virtual_2023.txt
# Normalizando arquivo: data/nlp\CC SICREDI COOMAMP\edital_ago_-_age_-_sicredi_coomamp_-_2021-3606688643084409760.txt
# Arquivo 'edital_ago_-_age_-_sicredi_coomamp_-_2021-3606688643084409760.txt' normalizado e salvo em: data/nlp_normalized\CC SICREDI COOMAMP\edital_ago_-_age_-_sicredi_coomamp_-_2021-3606688643084409760.txt
# Normalizando arquivo: data/nlp\CC SICREDI COOMAMP\inf901005545390122022_2002-manifesto.txt
# Arquivo 'inf901005545390122022_2002-manifesto.txt' normalizado e salvo em: data/nlp_normalized\CC SICREDI COOMAMP\inf901005545390122022_2002-manifesto.txt
# Normalizando arquivo: data/nlp\CC SICREDI COOMAMP\relatorio_2021_-_sicredi_coomamp-7845100396790685305.txt
# Arquivo 'relatorio_2021_-_sicredi_coomamp-7845100396790685305.txt' normalizado e salvo em: data/nlp_normalized\CC SICREDI COOMAMP\relatorio_2021_-_sicredi_coomamp-7845100396790685305.txt
# Normalizando arquivo: data/nlp\CC SICREDI COOMAMP\relatorio_sicredi_coomamp_-2022.txt
# Arquivo 'relatorio_sicredi_coomamp_-2022.txt' normalizado e salvo em: data/nlp_normalized\CC SICREDI COOMAMP\relatorio_sicredi_coomamp_-2022.txt
# Normalizando arquivo: data/nlp\CC SICREDI COOMAMP\sicredi_coomamp_122021-15867711859122017097.txt
# Arquivo 'sicredi_coomamp_122021-15867711859122017097.txt' normalizado e salvo em: data/nlp_normalized\CC SICREDI COOMAMP\sicredi_coomamp_122021-15867711859122017097.txt
# Normalizando arquivo: data/nlp\COOP POL FED - SICREDI POL\demonstracoes_financeiras_20222_sicredi_pol_rs_sc.txt
# Arquivo 'demonstracoes_financeiras_20222_sicredi_pol_rs_sc.txt' normalizado e salvo em: data/nlp_normalized\COOP POL FED - SICREDI POL\demonstracoes_financeiras_20222_sicredi_pol_rs_sc.txt
# Normalizando arquivo: data/nlp\COOP POL FED - SICREDI POL\edital_de_convocacao_age_2023-manifesto_sicredi_pol_rs_sc.txt
# Arquivo 'edital_de_convocacao_age_2023-manifesto_sicredi_pol_rs_sc.txt' normalizado e salvo em: data/nlp_normalized\COOP POL FED - SICREDI POL\edital_de_convocacao_age_2023-manifesto_sicredi_pol_rs_sc.txt
# Normalizando arquivo: data/nlp\COOP POL FED - SICREDI POL\edital_de_convocacao_ago_2023_sicredi_pol_rs_sc.txt
# Arquivo 'edital_de_convocacao_ago_2023_sicredi_pol_rs_sc.txt' normalizado e salvo em: data/nlp_normalized\COOP POL FED - SICREDI POL\edital_de_convocacao_ago_2023_sicredi_pol_rs_sc.txt
# Normalizando arquivo: data/nlp\COOP SICREDI AGROEMPRESARIAL\edital_ago_delegados_2023.txt
# Arquivo 'edital_ago_delegados_2023.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI AGROEMPRESARIAL\edital_ago_delegados_2023.txt
# Normalizando arquivo: data/nlp\COOP SICREDI AGROEMPRESARIAL\edital_assembleia_de_nucleos_2023.txt
# Arquivo 'edital_assembleia_de_nucleos_2023.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI AGROEMPRESARIAL\edital_assembleia_de_nucleos_2023.txt
# Normalizando arquivo: data/nlp\COOP SICREDI AGROEMPRESARIAL\relatorio_anual_2022_-_sicredi_agroempresarial.txt
# Arquivo 'relatorio_anual_2022_-_sicredi_agroempresarial.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI AGROEMPRESARIAL\relatorio_anual_2022_-_sicredi_agroempresarial.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ALIANÇA\edital_agn_2023_.txt
# Arquivo 'edital_agn_2023_.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ALIANÇA\edital_agn_2023_.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ALIANÇA\edital_ago_2023_alianca_rssces_final.txt
# Arquivo 'edital_ago_2023_alianca_rssces_final.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ALIANÇA\edital_ago_2023_alianca_rssces_final.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ALIANÇA\relatorio_2021_sicredi_alianca_rs_sc_es_web.txt
# Arquivo 'relatorio_2021_sicredi_alianca_rs_sc_es_web.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ALIANÇA\relatorio_2021_sicredi_alianca_rs_sc_es_web.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ALIANÇA\relatorio_2022_sicredi_alianca_rs_sc_es_-_web_-_baixa.txt
# Arquivo 'relatorio_2022_sicredi_alianca_rs_sc_es_-_web_-_baixa.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ALIANÇA\relatorio_2022_sicredi_alianca_rs_sc_es_-_web_-_baixa.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ALIANÇA RS_SC\edital_agn_2023_.txt
# Arquivo 'edital_agn_2023_.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ALIANÇA RS_SC\edital_agn_2023_.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ALIANÇA RS_SC\edital_ago_2023_alianca_rssces_final.txt
# Arquivo 'edital_ago_2023_alianca_rssces_final.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ALIANÇA RS_SC\edital_ago_2023_alianca_rssces_final.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ALIANÇA RS_SC\relatorio_2021_sicredi_alianca_rs_sc_es_web.txt
# Arquivo 'relatorio_2021_sicredi_alianca_rs_sc_es_web.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ALIANÇA RS_SC\relatorio_2021_sicredi_alianca_rs_sc_es_web.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ALIANÇA RS_SC\relatorio_2022_sicredi_alianca_rs_sc_es_-_web_-_baixa.txt
# Arquivo 'relatorio_2022_sicredi_alianca_rs_sc_es_-_web_-_baixa.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ALIANÇA RS_SC\relatorio_2022_sicredi_alianca_rs_sc_es_-_web_-_baixa.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ALT SERRA RS_SC\gir_book-elementos-graficos_ajustes_20230908_1.txt
# Arquivo 'gir_book-elementos-graficos_ajustes_20230908_1.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ALT SERRA RS_SC\gir_book-elementos-graficos_ajustes_20230908_1.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ALT SERRA RS_SC\media_coop_filer_public_2022_04_12_relatorio_2021_pronto.txt
# Arquivo 'media_coop_filer_public_2022_04_12_relatorio_2021_pronto.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ALT SERRA RS_SC\media_coop_filer_public_2022_04_12_relatorio_2021_pronto.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ALT SERRA RS_SC\media_coop_filer_public_2023_05_02_relatorio_2022_-_digital.txt
# Arquivo 'media_coop_filer_public_2023_05_02_relatorio_2022_-_digital.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ALT SERRA RS_SC\media_coop_filer_public_2023_05_02_relatorio_2022_-_digital.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ALT SERRA RS_SC\tutorial-de-acesso-campanha-assembleias-2024_1.txt
# Arquivo 'tutorial-de-acesso-campanha-assembleias-2024_1.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ALT SERRA RS_SC\tutorial-de-acesso-campanha-assembleias-2024_1.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ALTA NOROESTE SP\relatorio_anual_2021_sicredi_alta_noroeste_sp_whats-11945918522868603044.txt
# Arquivo 'relatorio_anual_2021_sicredi_alta_noroeste_sp_whats-11945918522868603044.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ALTA NOROESTE SP\relatorio_anual_2021_sicredi_alta_noroeste_sp_whats-11945918522868603044.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ALTSERTÃO PARAIBANO\2216_-_edital_agn_2023.txt
# Arquivo '2216_-_edital_agn_2023.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ALTSERTÃO PARAIBANO\2216_-_edital_agn_2023.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARACAJU\demonstracoes_financeiras_2022_sicredi_aracaju.txt
# Arquivo 'demonstracoes_financeiras_2022_sicredi_aracaju.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARACAJU\demonstracoes_financeiras_2022_sicredi_aracaju.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARACAJU\edital_assembleia_nucleos_2023_presencial_ua02.txt
# Arquivo 'edital_assembleia_nucleos_2023_presencial_ua02.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARACAJU\edital_assembleia_nucleos_2023_presencial_ua02.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARACAJU\edital_assembleia_nucleos_2023_presencial_ua03.txt
# Arquivo 'edital_assembleia_nucleos_2023_presencial_ua03.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARACAJU\edital_assembleia_nucleos_2023_presencial_ua03.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARACAJU\edital_assembleia_nucleos_2023_presencial_ua04.txt
# Arquivo 'edital_assembleia_nucleos_2023_presencial_ua04.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARACAJU\edital_assembleia_nucleos_2023_presencial_ua04.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARACAJU\edital_assembleia_nucleos_2023_presencial_ua05.txt
# Arquivo 'edital_assembleia_nucleos_2023_presencial_ua05.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARACAJU\edital_assembleia_nucleos_2023_presencial_ua05.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARACAJU\edital_assembleia_nucleos_2023_presencial_ua07.txt
# Arquivo 'edital_assembleia_nucleos_2023_presencial_ua07.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARACAJU\edital_assembleia_nucleos_2023_presencial_ua07.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARACAJU\edital_assembleia_nucleos_2023_presencial_ua08.txt
# Arquivo 'edital_assembleia_nucleos_2023_presencial_ua08.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARACAJU\edital_assembleia_nucleos_2023_presencial_ua08.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARACAJU\edital_assembleia_nucleos_2023_presencial_ua09.txt
# Arquivo 'edital_assembleia_nucleos_2023_presencial_ua09.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARACAJU\edital_assembleia_nucleos_2023_presencial_ua09.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARACAJU\estatuto_social_age_2023.txt
# Arquivo 'estatuto_social_age_2023.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARACAJU\estatuto_social_age_2023.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARACAJU\media_coop_filer_public_2023_01_24_regulamento_pertencer_celeiro.txt
# Arquivo 'media_coop_filer_public_2023_01_24_regulamento_pertencer_celeiro.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARACAJU\media_coop_filer_public_2023_01_24_regulamento_pertencer_celeiro.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARACAJU\relatorio_de_gestao_-_sicredi_aracaju_2022-1.txt
# Arquivo 'relatorio_de_gestao_-_sicredi_aracaju_2022-1.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARACAJU\relatorio_de_gestao_-_sicredi_aracaju_2022-1.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARACAJU\relatorio_de_gestao_2022.txt
# Arquivo 'relatorio_de_gestao_2022.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARACAJU\relatorio_de_gestao_2022.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARACAJU\tabela_de_tarifas_2024.txt
# Arquivo 'tabela_de_tarifas_2024.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARACAJU\tabela_de_tarifas_2024.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARAXINGÚ\02_querencia_edital_assembleia_nucleos_2023_digital-manifesto.txt
# Arquivo '02_querencia_edital_assembleia_nucleos_2023_digital-manifesto.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARAXINGÚ\02_querencia_edital_assembleia_nucleos_2023_digital-manifesto.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARAXINGÚ\04_ribeirao_cascalheira_edital_assembleia_nucleos_2023_digital-manifesto.txt
# Arquivo '04_ribeirao_cascalheira_edital_assembleia_nucleos_2023_digital-manifesto.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARAXINGÚ\04_ribeirao_cascalheira_edital_assembleia_nucleos_2023_digital-manifesto.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARAXINGÚ\05_canarana_edital_assembleia_nucleos_2023_digital-manifesto.txt
# Arquivo '05_canarana_edital_assembleia_nucleos_2023_digital-manifesto.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARAXINGÚ\05_canarana_edital_assembleia_nucleos_2023_digital-manifesto.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARAXINGÚ\08_vila_rica_edital_assembleia_nucleos_2023_digital-manifesto.txt
# Arquivo '08_vila_rica_edital_assembleia_nucleos_2023_digital-manifesto.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARAXINGÚ\08_vila_rica_edital_assembleia_nucleos_2023_digital-manifesto.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARAXINGÚ\09_confresa_edital_assembleia_nucleos_2023_digital-manifesto.txt
# Arquivo '09_confresa_edital_assembleia_nucleos_2023_digital-manifesto.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARAXINGÚ\09_confresa_edital_assembleia_nucleos_2023_digital-manifesto.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARAXINGÚ\11_bom_jesus_do_araguaia_edital_assembleia_nucleos_2023_digital-manifesto.txt
# Arquivo '11_bom_jesus_do_araguaia_edital_assembleia_nucleos_2023_digital-manifesto.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARAXINGÚ\11_bom_jesus_do_araguaia_edital_assembleia_nucleos_2023_digital-manifesto.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARAXINGÚ\12_santa_cruz_do_xingu_edital_assembleia_nucleos_2023_digital-manifesto.txt
# Arquivo '12_santa_cruz_do_xingu_edital_assembleia_nucleos_2023_digital-manifesto.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARAXINGÚ\12_santa_cruz_do_xingu_edital_assembleia_nucleos_2023_digital-manifesto.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARAXINGÚ\13_cocalinho_edital_assembleia_nucleos_2023_digital-manifesto.txt
# Arquivo '13_cocalinho_edital_assembleia_nucleos_2023_digital-manifesto.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARAXINGÚ\13_cocalinho_edital_assembleia_nucleos_2023_digital-manifesto.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARAXINGÚ\14_nova_xavantina_edital_assembleia_nucleos_2023_digital-manifesto.txt
# Arquivo '14_nova_xavantina_edital_assembleia_nucleos_2023_digital-manifesto.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARAXINGÚ\14_nova_xavantina_edital_assembleia_nucleos_2023_digital-manifesto.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARAXINGÚ\15_alto_boa_vista_edital_assembleia_nucleos_2023_digital-manifesto.txt
# Arquivo '15_alto_boa_vista_edital_assembleia_nucleos_2023_digital-manifesto.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARAXINGÚ\15_alto_boa_vista_edital_assembleia_nucleos_2023_digital-manifesto.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARAXINGÚ\ag_03_edital_assembleia_nucleos_2023_presencial_gaucha_do_norte-manifesto.txt
# Arquivo 'ag_03_edital_assembleia_nucleos_2023_presencial_gaucha_do_norte-manifesto.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARAXINGÚ\ag_03_edital_assembleia_nucleos_2023_presencial_gaucha_do_norte-manifesto.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARAXINGÚ\ag_06_edital_assembleia_nucleos_2023_presencial_sao_jose_do_xingu-manifesto.txt
# Arquivo 'ag_06_edital_assembleia_nucleos_2023_presencial_sao_jose_do_xingu-manifesto.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARAXINGÚ\ag_06_edital_assembleia_nucleos_2023_presencial_sao_jose_do_xingu-manifesto.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARAXINGÚ\ag_07_edital_assembleia_nucleos_2023_presencial_agua_boa-manifesto.txt
# Arquivo 'ag_07_edital_assembleia_nucleos_2023_presencial_agua_boa-manifesto.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARAXINGÚ\ag_07_edital_assembleia_nucleos_2023_presencial_agua_boa-manifesto.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARAXINGÚ\ag_16_edital_assembleia_nucleos_2023_presencial_campinapolis-manifesto.txt
# Arquivo 'ag_16_edital_assembleia_nucleos_2023_presencial_campinapolis-manifesto.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARAXINGÚ\ag_16_edital_assembleia_nucleos_2023_presencial_campinapolis-manifesto.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARAXINGÚ\ag_17_edital_assembleia_nucleos_2023_presencial_santa_terezinha-manifesto.txt
# Arquivo 'ag_17_edital_assembleia_nucleos_2023_presencial_santa_terezinha-manifesto.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARAXINGÚ\ag_17_edital_assembleia_nucleos_2023_presencial_santa_terezinha-manifesto.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARAXINGÚ\ag_18_edital_assembleia_nucleos_2023_presencial_britania-manifesto.txt
# Arquivo 'ag_18_edital_assembleia_nucleos_2023_presencial_britania-manifesto.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARAXINGÚ\ag_18_edital_assembleia_nucleos_2023_presencial_britania-manifesto.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARAXINGÚ\ag_19_edital_assembleia_nucleos_2023_presencial_jussara-manifesto.txt
# Arquivo 'ag_19_edital_assembleia_nucleos_2023_presencial_jussara-manifesto.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARAXINGÚ\ag_19_edital_assembleia_nucleos_2023_presencial_jussara-manifesto.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARAXINGÚ\ag_20_edital_assembleia_nucleos_2023_presencial_espigao_do_leste-manifesto.txt
# Arquivo 'ag_20_edital_assembleia_nucleos_2023_presencial_espigao_do_leste-manifesto.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARAXINGÚ\ag_20_edital_assembleia_nucleos_2023_presencial_espigao_do_leste-manifesto.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARAXINGÚ\ag_21_edital_assembleia_nucleos_2023_presencial_ribeiraozinho-manifesto.txt
# Arquivo 'ag_21_edital_assembleia_nucleos_2023_presencial_ribeiraozinho-manifesto.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARAXINGÚ\ag_21_edital_assembleia_nucleos_2023_presencial_ribeiraozinho-manifesto.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARAXINGÚ\ag_22_edital_assembleia_nucleos_2023_presencial_aragarcas-manifesto.txt
# Arquivo 'ag_22_edital_assembleia_nucleos_2023_presencial_aragarcas-manifesto.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARAXINGÚ\ag_22_edital_assembleia_nucleos_2023_presencial_aragarcas-manifesto.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARAXINGÚ\ag_23_edital_assembleia_nucleos_2023_presencial_porto_alegre_do_norte-manifesto.txt
# Arquivo 'ag_23_edital_assembleia_nucleos_2023_presencial_porto_alegre_do_norte-manifesto.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARAXINGÚ\ag_23_edital_assembleia_nucleos_2023_presencial_porto_alegre_do_norte-manifesto.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARAXINGÚ\ag_24_edital_assembleia_nucleos_2023_presencial_mozarlandia-manifesto.txt
# Arquivo 'ag_24_edital_assembleia_nucleos_2023_presencial_mozarlandia-manifesto.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARAXINGÚ\ag_24_edital_assembleia_nucleos_2023_presencial_mozarlandia-manifesto.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARAXINGÚ\ag_25_edital_assembleia_nucleos_2023_presencial_montes_claros-manifesto.txt
# Arquivo 'ag_25_edital_assembleia_nucleos_2023_presencial_montes_claros-manifesto.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARAXINGÚ\ag_25_edital_assembleia_nucleos_2023_presencial_montes_claros-manifesto.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARAXINGÚ\ag_26_edital_assembleia_nucleos_2023_presencial_bom_jardim-manifesto.txt
# Arquivo 'ag_26_edital_assembleia_nucleos_2023_presencial_bom_jardim-manifesto.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARAXINGÚ\ag_26_edital_assembleia_nucleos_2023_presencial_bom_jardim-manifesto.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARAXINGÚ\circular_assembleia_delegados_2023_presencial_pdfa-manifesto.txt
# Arquivo 'circular_assembleia_delegados_2023_presencial_pdfa-manifesto.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARAXINGÚ\circular_assembleia_delegados_2023_presencial_pdfa-manifesto.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARAXINGÚ\demonstracoes_financeiras_semestral_2023.txt
# Arquivo 'demonstracoes_financeiras_semestral_2023.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARAXINGÚ\demonstracoes_financeiras_semestral_2023.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARAXINGÚ\dfs_2023.txt
# Arquivo 'dfs_2023.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARAXINGÚ\dfs_2023.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARAXINGÚ\edital_assembleia_delegados_2023_presencial_finalizado_pdfa-manifesto.txt
# Arquivo 'edital_assembleia_delegados_2023_presencial_finalizado_pdfa-manifesto.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARAXINGÚ\edital_assembleia_delegados_2023_presencial_finalizado_pdfa-manifesto.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARAXINGÚ\edital_assembleia_nucleos_2021_digital_-_araxingu_visto_publicacao_com_qrcode.txt
# Arquivo 'edital_assembleia_nucleos_2021_digital_-_araxingu_visto_publicacao_com_qrcode.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARAXINGÚ\edital_assembleia_nucleos_2021_digital_-_araxingu_visto_publicacao_com_qrcode.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARAXINGÚ\politica_sucessao_cargos_alta_administracao_ago_2023.txt
# Arquivo 'politica_sucessao_cargos_alta_administracao_ago_2023.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARAXINGÚ\politica_sucessao_cargos_alta_administracao_ago_2023.txt
# Normalizando arquivo: data/nlp\COOP SICREDI ARAXINGÚ\regulamento_pertencer_ccn_aprovado_em_25_03_2022.txt
# Arquivo 'regulamento_pertencer_ccn_aprovado_em_25_03_2022.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI ARAXINGÚ\regulamento_pertencer_ccn_aprovado_em_25_03_2022.txt
# Normalizando arquivo: data/nlp\COOP SICREDI BIOMAS\185689_job_20223a_relatorio_anual_2022_pocket_digital_aa160323_original.txt
# Arquivo '185689_job_20223a_relatorio_anual_2022_pocket_digital_aa160323_original.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI BIOMAS\185689_job_20223a_relatorio_anual_2022_pocket_digital_aa160323_original.txt
# Normalizando arquivo: data/nlp\COOP SICREDI BIOMAS\demonstracoes_financeiras_2022.txt
# Arquivo 'demonstracoes_financeiras_2022.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI BIOMAS\demonstracoes_financeiras_2022.txt
# Normalizando arquivo: data/nlp\COOP SICREDI BIOMAS\estatuto_2022_arquivo_separado_1.txt
# Arquivo 'estatuto_2022_arquivo_separado_1.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI BIOMAS\estatuto_2022_arquivo_separado_1.txt
# Normalizando arquivo: data/nlp\COOP SICREDI BIOMAS\relatorio_anual_2022_-_sicredi_biomas.txt
# Arquivo 'relatorio_anual_2022_-_sicredi_biomas.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI BIOMAS\relatorio_anual_2022_-_sicredi_biomas.txt
# Normalizando arquivo: data/nlp\COOP SICREDI BIOMAS\relatorio_sicredi_biomas_2021.txt
# Arquivo 'relatorio_sicredi_biomas_2021.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI BIOMAS\relatorio_sicredi_biomas_2021.txt
# Normalizando arquivo: data/nlp\COOP SICREDI BIOMAS\sicredi_-_relatorio_anual_2020.txt
# Arquivo 'sicredi_-_relatorio_anual_2020.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI BIOMAS\sicredi_-_relatorio_anual_2020.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CAMINHO DAS ÁGUAS RS\33d5b5f7fd831e01378b0c5b510477fc-7145716331102295327.txt
# Arquivo '33d5b5f7fd831e01378b0c5b510477fc-7145716331102295327.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CAMINHO DAS ÁGUAS RS\33d5b5f7fd831e01378b0c5b510477fc-7145716331102295327.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CAMINHO DAS ÁGUAS RS\anual-9656246937758427054.txt
# Arquivo 'anual-9656246937758427054.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CAMINHO DAS ÁGUAS RS\anual-9656246937758427054.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CAMINHO DAS ÁGUAS RS\auditoria-14765613745617040231.txt
# Arquivo 'auditoria-14765613745617040231.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CAMINHO DAS ÁGUAS RS\auditoria-14765613745617040231.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CAMINHO DAS ÁGUAS RS\revista-catavento-2023.txt
# Arquivo 'revista-catavento-2023.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CAMINHO DAS ÁGUAS RS\revista-catavento-2023.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CAMPO GRANDE\demonstracoes_financeiras_2022_-_sicredi_campo_grande_ms.txt
# Arquivo 'demonstracoes_financeiras_2022_-_sicredi_campo_grande_ms.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CAMPO GRANDE\demonstracoes_financeiras_2022_-_sicredi_campo_grande_ms.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CAMPO GRANDE\edital_age_outubro_2023.txt
# Arquivo 'edital_age_outubro_2023.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CAMPO GRANDE\edital_age_outubro_2023.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CAMPO GRANDE\edital_ago_2023_sicredi_campo_grande.txt
# Arquivo 'edital_ago_2023_sicredi_campo_grande.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CAMPO GRANDE\edital_ago_2023_sicredi_campo_grande.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CAMPO GRANDE\estatuto_social_2022.txt
# Arquivo 'estatuto_social_2022.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CAMPO GRANDE\estatuto_social_2022.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CAMPO GRANDE\informativo2023_sicredi_campo_grande_ms.txt
# Arquivo 'informativo2023_sicredi_campo_grande_ms.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CAMPO GRANDE\informativo2023_sicredi_campo_grande_ms.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CAMPO GRANDE\relatorio_2022_vweb_.txt
# Arquivo 'relatorio_2022_vweb_.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CAMPO GRANDE\relatorio_2022_vweb_.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CAMPO GRANDE\relatorio_anual_2021_sicredi_campo_grande_ms.txt
# Arquivo 'relatorio_anual_2021_sicredi_campo_grande_ms.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CAMPO GRANDE\relatorio_anual_2021_sicredi_campo_grande_ms.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CAMPO GRANDE\relatorio_anual_de_sustentabilidade_2022.txt
# Arquivo 'relatorio_anual_de_sustentabilidade_2022.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CAMPO GRANDE\relatorio_anual_de_sustentabilidade_2022.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CAMPO GRANDE\sicredi-campo-grande-ms-122017.txt
# Arquivo 'sicredi-campo-grande-ms-122017.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CAMPO GRANDE\sicredi-campo-grande-ms-122017.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CAMPO GRANDE\sicredi-campo-grande-ms-122018.txt
# Arquivo 'sicredi-campo-grande-ms-122018.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CAMPO GRANDE\sicredi-campo-grande-ms-122018.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CAMPO GRANDE\sicredi-campo-grande-ms-122019.txt
# Arquivo 'sicredi-campo-grande-ms-122019.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CAMPO GRANDE\sicredi-campo-grande-ms-122019.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CAMPO GRANDE\sicredi_campo_grande_ms_122020.txt
# Arquivo 'sicredi_campo_grande_ms_122020.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CAMPO GRANDE\sicredi_campo_grande_ms_122020.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CAMPO GRANDE\sicredi_campo_grande_ms_122021.txt
# Arquivo 'sicredi_campo_grande_ms_122021.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CAMPO GRANDE\sicredi_campo_grande_ms_122021.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CELEIRO DO MT\edital_fundo_social_2022_sicredi_celeiro_mt_rr.txt
# Arquivo 'edital_fundo_social_2022_sicredi_celeiro_mt_rr.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CELEIRO DO MT\edital_fundo_social_2022_sicredi_celeiro_mt_rr.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CELEIRO DO MT\estatuto_social_-_sicredi_celeiro_mtrr_out2023.txt
# Arquivo 'estatuto_social_-_sicredi_celeiro_mtrr_out2023.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CELEIRO DO MT\estatuto_social_-_sicredi_celeiro_mtrr_out2023.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CELEIRO DO MT\regulamento_pertencer_2022.txt
# Arquivo 'regulamento_pertencer_2022.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CELEIRO DO MT\regulamento_pertencer_2022.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CELEIRO DO MT\relatorio_anual_2021.txt
# Arquivo 'relatorio_anual_2021.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CELEIRO DO MT\relatorio_anual_2021.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CELEIRO DO MT\relatorio_anual_2022_sicredi_celeiro_mtrr.txt
# Arquivo 'relatorio_anual_2022_sicredi_celeiro_mtrr.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CELEIRO DO MT\relatorio_anual_2022_sicredi_celeiro_mtrr.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CELEIRO DO MT\relatorio_sustentabilidade_sicredi_2022.txt
# Arquivo 'relatorio_sustentabilidade_sicredi_2022.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CELEIRO DO MT\relatorio_sustentabilidade_sicredi_2022.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CELEIRO OESTE\2022_edital_assembleia_geral_de_delegados.txt
# Arquivo '2022_edital_assembleia_geral_de_delegados.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CELEIRO OESTE\2022_edital_assembleia_geral_de_delegados.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CELEIRO OESTE\2022_edital_de_convocacao_assembleia_de_nucleo.txt
# Arquivo '2022_edital_de_convocacao_assembleia_de_nucleo.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CELEIRO OESTE\2022_edital_de_convocacao_assembleia_de_nucleo.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CELEIRO OESTE\3_e_parecer_do_conselho_fiscal_-_demonstracoes_2021.txt
# Arquivo '3_e_parecer_do_conselho_fiscal_-_demonstracoes_2021.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CELEIRO OESTE\3_e_parecer_do_conselho_fiscal_-_demonstracoes_2021.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CELEIRO OESTE\apresentacao_assembleias_de_nucleos_2023_1.txt
# Arquivo 'apresentacao_assembleias_de_nucleos_2023_1.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CELEIRO OESTE\apresentacao_assembleias_de_nucleos_2023_1.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CELEIRO OESTE\apresentacao_assembleia_de_nucleos_2021.txt
# Arquivo 'apresentacao_assembleia_de_nucleos_2021.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CELEIRO OESTE\apresentacao_assembleia_de_nucleos_2021.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CELEIRO OESTE\apresentacao_assembleia_de_nucleo_2022.txt
# Arquivo 'apresentacao_assembleia_de_nucleo_2022.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CELEIRO OESTE\apresentacao_assembleia_de_nucleo_2022.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CELEIRO OESTE\assembleia_digital_tutorial_de_acesso_-_assembleias_2022_1.txt
# Arquivo 'assembleia_digital_tutorial_de_acesso_-_assembleias_2022_1.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CELEIRO OESTE\assembleia_digital_tutorial_de_acesso_-_assembleias_2022_1.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CELEIRO OESTE\ata_e_estatuto_social_2020.txt
# Arquivo 'ata_e_estatuto_social_2020.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CELEIRO OESTE\ata_e_estatuto_social_2020.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CELEIRO OESTE\certidao_2020_ageo_30062020_200639650_estatuto_jucems.txt
# Arquivo 'certidao_2020_ageo_30062020_200639650_estatuto_jucems.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CELEIRO OESTE\certidao_2020_ageo_30062020_200639650_estatuto_jucems.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CELEIRO OESTE\certidao_2020_ageo_30062020_goe2000223170_estatuto_juceg.txt
# Arquivo 'certidao_2020_ageo_30062020_goe2000223170_estatuto_juceg.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CELEIRO OESTE\certidao_2020_ageo_30062020_goe2000223170_estatuto_juceg.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CELEIRO OESTE\check_list_sites_-_para_obtencao_dos_documentos_eleicoes_2022.txt
# Arquivo 'check_list_sites_-_para_obtencao_dos_documentos_eleicoes_2022.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CELEIRO OESTE\check_list_sites_-_para_obtencao_dos_documentos_eleicoes_2022.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CELEIRO OESTE\codigo_eleitoral_de_cooperativa_singular.txt
# Arquivo 'codigo_eleitoral_de_cooperativa_singular.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CELEIRO OESTE\codigo_eleitoral_de_cooperativa_singular.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CELEIRO OESTE\edital_de_convocacao_assembleia_de_nucleo_2023.txt
# Arquivo 'edital_de_convocacao_assembleia_de_nucleo_2023.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CELEIRO OESTE\edital_de_convocacao_assembleia_de_nucleo_2023.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CELEIRO OESTE\edital__-_assembleia_geral_ordinaria_e_extraordinaria_14-04-2023.txt
# Arquivo 'edital__-_assembleia_geral_ordinaria_e_extraordinaria_14-04-2023.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CELEIRO OESTE\edital__-_assembleia_geral_ordinaria_e_extraordinaria_14-04-2023.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CELEIRO OESTE\informativo_2023.txt
# Arquivo 'informativo_2023.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CELEIRO OESTE\informativo_2023.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CELEIRO OESTE\informativo_da_cooperativa_abril_2022_-_online.txt
# Arquivo 'informativo_da_cooperativa_abril_2022_-_online.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CELEIRO OESTE\informativo_da_cooperativa_abril_2022_-_online.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CELEIRO OESTE\informativo_da_cooperativa_fevereiro_2022_-_online.txt
# Arquivo 'informativo_da_cooperativa_fevereiro_2022_-_online.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CELEIRO OESTE\informativo_da_cooperativa_fevereiro_2022_-_online.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CELEIRO OESTE\informativo_da_cooperativa_junho__2022_-_online.txt
# Arquivo 'informativo_da_cooperativa_junho__2022_-_online.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CELEIRO OESTE\informativo_da_cooperativa_junho__2022_-_online.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CELEIRO OESTE\instrucao_normativa_bcb_n_299_de_30-08-2022.txt
# Arquivo 'instrucao_normativa_bcb_n_299_de_30-08-2022.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CELEIRO OESTE\instrucao_normativa_bcb_n_299_de_30-08-2022.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CELEIRO OESTE\instrucao_normativa_bcb_n_77_de_11-02-2021.txt
# Arquivo 'instrucao_normativa_bcb_n_77_de_11-02-2021.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CELEIRO OESTE\instrucao_normativa_bcb_n_77_de_11-02-2021.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CELEIRO OESTE\instrucao_normativa_no_81_de_10_de_junho_de_2020_-_anexo_vi.txt
# Arquivo 'instrucao_normativa_no_81_de_10_de_junho_de_2020_-_anexo_vi.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CELEIRO OESTE\instrucao_normativa_no_81_de_10_de_junho_de_2020_-_anexo_vi.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CELEIRO OESTE\resolucao_4122-2012_cmn_-_bacen.txt
# Arquivo 'resolucao_4122-2012_cmn_-_bacen.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CELEIRO OESTE\resolucao_4122-2012_cmn_-_bacen.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CELEIRO OESTE\resolucao_cmn_n_4970_de_25-11-2021.txt
# Arquivo 'resolucao_cmn_n_4970_de_25-11-2021.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CELEIRO OESTE\resolucao_cmn_n_4970_de_25-11-2021.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CELEIRO OESTE\sicredi_celeiro_centro_oeste_062021.txt
# Arquivo 'sicredi_celeiro_centro_oeste_062021.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CELEIRO OESTE\sicredi_celeiro_centro_oeste_062021.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CELEIRO OESTE\voto_cad_025_20222_politicas_sucessao.txt
# Arquivo 'voto_cad_025_20222_politicas_sucessao.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CELEIRO OESTE\voto_cad_025_20222_politicas_sucessao.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CEN OEST PAULISTA\3022relatorio_anual_2019.txt
# Arquivo '3022relatorio_anual_2019.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CEN OEST PAULISTA\3022relatorio_anual_2019.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CEN OEST PAULISTA\3022relatorio_anual_2020.txt
# Arquivo '3022relatorio_anual_2020.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CEN OEST PAULISTA\3022relatorio_anual_2020.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CEN OEST PAULISTA\3022relatorio_anual_2021.txt
# Arquivo '3022relatorio_anual_2021.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CEN OEST PAULISTA\3022relatorio_anual_2021.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CEN OEST PAULISTA\3022relatorio_anual_2022.txt
# Arquivo '3022relatorio_anual_2022.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CEN OEST PAULISTA\3022relatorio_anual_2022.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CEN OEST PAULISTA\codigo_de_conduta_digital2020.txt
# Arquivo 'codigo_de_conduta_digital2020.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CEN OEST PAULISTA\codigo_de_conduta_digital2020.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CEN OEST PAULISTA\media_produtos_filer_public_2023_03_10_sicredi_centro_oeste_paulista.txt
# Arquivo 'media_produtos_filer_public_2023_03_10_sicredi_centro_oeste_paulista.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CEN OEST PAULISTA\media_produtos_filer_public_2023_03_10_sicredi_centro_oeste_paulista.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CEN OEST PAULISTA\media_produtos_filer_public_2023_08_30_sicredi_centro_oeste_paulista_062023.txt
# Arquivo 'media_produtos_filer_public_2023_08_30_sicredi_centro_oeste_paulista_062023.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CEN OEST PAULISTA\media_produtos_filer_public_2023_08_30_sicredi_centro_oeste_paulista_062023.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CEN OEST PAULISTA\norma_prsprj_2023_estatutarios_v_11_2023.txt
# Arquivo 'norma_prsprj_2023_estatutarios_v_11_2023.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CEN OEST PAULISTA\norma_prsprj_2023_estatutarios_v_11_2023.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CENT PERNAMBUCANA\comunicado_cheque_especial-6232942346235174507.txt
# Arquivo 'comunicado_cheque_especial-6232942346235174507.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CENT PERNAMBUCANA\comunicado_cheque_especial-6232942346235174507.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CENT PERNAMBUCANA\demonstracoes_financeiras_inf901041255225122022_2206.txt
# Arquivo 'demonstracoes_financeiras_inf901041255225122022_2206.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CENT PERNAMBUCANA\demonstracoes_financeiras_inf901041255225122022_2206.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CENT PERNAMBUCANA\demostracoes_financeiras__2022_08_26_sicredi_centro_pernambucana_062022.txt
# Arquivo 'demostracoes_financeiras__2022_08_26_sicredi_centro_pernambucana_062022.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CENT PERNAMBUCANA\demostracoes_financeiras__2022_08_26_sicredi_centro_pernambucana_062022.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CENT PERNAMBUCANA\edital_de_convocacao-10762445990255379741.txt
# Arquivo 'edital_de_convocacao-10762445990255379741.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CENT PERNAMBUCANA\edital_de_convocacao-10762445990255379741.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CENT PERNAMBUCANA\edital_de_convocacao_agoe_14042023.txt
# Arquivo 'edital_de_convocacao_agoe_14042023.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CENT PERNAMBUCANA\edital_de_convocacao_agoe_14042023.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CENT PERNAMBUCANA\estatuto_social_2021-15396830165694342493.txt
# Arquivo 'estatuto_social_2021-15396830165694342493.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CENT PERNAMBUCANA\estatuto_social_2021-15396830165694342493.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CENT PERNAMBUCANA\regulamento_pertencer_2023.txt
# Arquivo 'regulamento_pertencer_2023.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CENT PERNAMBUCANA\regulamento_pertencer_2023.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CENT PERNAMBUCANA\relatorio_anual_2021-4075943696049711726.txt
# Arquivo 'relatorio_anual_2021-4075943696049711726.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CENT PERNAMBUCANA\relatorio_anual_2021-4075943696049711726.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CENT PERNAMBUCANA\relatorio_anual_sicredi_2022_final.txt
# Arquivo 'relatorio_anual_sicredi_2022_final.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CENT PERNAMBUCANA\relatorio_anual_sicredi_2022_final.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CENT PERNAMBUCANA\sicredi_centro_pernambucana_122021-1550413438529123708.txt
# Arquivo 'sicredi_centro_pernambucana_122021-1550413438529123708.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CENT PERNAMBUCANA\sicredi_centro_pernambucana_122021-1550413438529123708.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CENT SUL PR_SC_RJ\edital_ago_2023.txt
# Arquivo 'edital_ago_2023.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CENT SUL PR_SC_RJ\edital_ago_2023.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CENTRO LESTE RS\assembleias-2021_apresentacao-12709167400161642065.txt
# Arquivo 'assembleias-2021_apresentacao-12709167400161642065.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CENTRO LESTE RS\assembleias-2021_apresentacao-12709167400161642065.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CENTRO LESTE RS\edital_ago2023.txt
# Arquivo 'edital_ago2023.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CENTRO LESTE RS\edital_ago2023.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CENTRO LESTE RS\edital_convocacao_agn_07-03-23.txt
# Arquivo 'edital_convocacao_agn_07-03-23.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CENTRO LESTE RS\edital_convocacao_agn_07-03-23.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CENTRO LESTE RS\edital_de_convocacao_assembleia_de_nucleo_11-2023.txt
# Arquivo 'edital_de_convocacao_assembleia_de_nucleo_11-2023.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CENTRO LESTE RS\edital_de_convocacao_assembleia_de_nucleo_11-2023.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CENTRO LESTE RS\edital_de_convocacao_assembleia_extraordinaria_de_delegados_11-2023.txt
# Arquivo 'edital_de_convocacao_assembleia_extraordinaria_de_delegados_11-2023.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CENTRO LESTE RS\edital_de_convocacao_assembleia_extraordinaria_de_delegados_11-2023.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CENTRO LESTE RS\relatorio_anual_2022.txt
# Arquivo 'relatorio_anual_2022.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CENTRO LESTE RS\relatorio_anual_2022.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CENTRO SERRA\regulamento_pertencer_2022.txt
# Arquivo 'regulamento_pertencer_2022.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CENTRO SERRA\regulamento_pertencer_2022.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CENTRO-SUL MS_BA\edital_agoe_2023.txt
# Arquivo 'edital_agoe_2023.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CENTRO-SUL MS_BA\edital_agoe_2023.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CENTRO-SUL MS_BA\edital_ago_2020-assembleia_eletronica-validado_central-7143024677017560903.txt
# Arquivo 'edital_ago_2020-assembleia_eletronica-validado_central-7143024677017560903.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CENTRO-SUL MS_BA\edital_ago_2020-assembleia_eletronica-validado_central-7143024677017560903.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CENTRO-SUL MS_BA\edital_de_concovacao_assembleias_2022-16952687042595788108.txt
# Arquivo 'edital_de_concovacao_assembleias_2022-16952687042595788108.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CENTRO-SUL MS_BA\edital_de_concovacao_assembleias_2022-16952687042595788108.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CENTRO-SUL MS_BA\edital_de_convocacao_-_agn_2020.txt
# Arquivo 'edital_de_convocacao_-_agn_2020.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CENTRO-SUL MS_BA\edital_de_convocacao_-_agn_2020.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CERRADO GO\edital_de_ago_2023_publicacao_final_v2.txt
# Arquivo 'edital_de_ago_2023_publicacao_final_v2.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CERRADO GO\edital_de_ago_2023_publicacao_final_v2.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CERRADO GO\fundo_social_2023.txt
# Arquivo 'fundo_social_2023.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CERRADO GO\fundo_social_2023.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CERRADO GO\fundo_social_2023_edital_inscricoes_prorrogadas.txt
# Arquivo 'fundo_social_2023_edital_inscricoes_prorrogadas.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CERRADO GO\fundo_social_2023_edital_inscricoes_prorrogadas.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CERRADO GO\media_coop_filer_public_2023_03_29_regulamento_fundo_social_2023_inscricoes_prorrogadas.txt
# Arquivo 'media_coop_filer_public_2023_03_29_regulamento_fundo_social_2023_inscricoes_prorrogadas.txt' normalizado e salvo em: data/nlp_normalized\COOP SICREDI CERRADO GO\media_coop_filer_public_2023_03_29_regulamento_fundo_social_2023_inscricoes_prorrogadas.txt
# Normalizando arquivo: data/nlp\COOP SICREDI CERRADO GO\relatorio_anual_sicredi_cerrado_2021_alterado_baixa.txt
# ...
# Arquivo 'regulamento_eleitoral_interno_2023.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CAMPOS GERAIS E GRANDE CURI\regulamento_eleitoral_interno_2023.txt
# Normalizando arquivo: data/nlp\SICREDI CAMPOS GERAIS E GRANDE CURI\regulamento_pertencer_2022.txt
# Arquivo 'regulamento_pertencer_2022.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CAMPOS GERAIS E GRANDE CURI\regulamento_pertencer_2022.txt
# Normalizando arquivo: data/nlp\SICREDI CAMPOS GERAIS E GRANDE CURI\regulamento_pertencer_2023.txt
# Arquivo 'regulamento_pertencer_2023.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CAMPOS GERAIS E GRANDE CURI\regulamento_pertencer_2023.txt
# Normalizando arquivo: data/nlp\SICREDI CAMPOS GERAIS E GRANDE CURI\relatorio_anual_-_2021_-_digital.txt
# Arquivo 'relatorio_anual_-_2021_-_digital.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CAMPOS GERAIS E GRANDE CURI\relatorio_anual_-_2021_-_digital.txt
# Normalizando arquivo: data/nlp\SICREDI CAMPOS GERAIS E GRANDE CURI\relatorio_anual_2022_virtual_sicredi.txt
# Arquivo 'relatorio_anual_2022_virtual_sicredi.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CAMPOS GERAIS E GRANDE CURI\relatorio_anual_2022_virtual_sicredi.txt
# Normalizando arquivo: data/nlp\SICREDI CEARÁ\assinatura_digital_ata_age_2020_-_reforma_estatutaria-11407758292763845363.txt
# Arquivo 'assinatura_digital_ata_age_2020_-_reforma_estatutaria-11407758292763845363.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CEARÁ\assinatura_digital_ata_age_2020_-_reforma_estatutaria-11407758292763845363.txt
# Normalizando arquivo: data/nlp\SICREDI CEARÁ\edital-convocacao-eleicao-de-delegados-voto-eletronico-2019_2022-15630361363684965094.txt
# Arquivo 'edital-convocacao-eleicao-de-delegados-voto-eletronico-2019_2022-15630361363684965094.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CEARÁ\edital-convocacao-eleicao-de-delegados-voto-eletronico-2019_2022-15630361363684965094.txt
# Normalizando arquivo: data/nlp\SICREDI CEARÁ\edital-convocacao-eleicao-de-delegados-voto-eletronico-2019_2022-_1-14295251612792152872.txt
# Arquivo 'edital-convocacao-eleicao-de-delegados-voto-eletronico-2019_2022-_1-14295251612792152872.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CEARÁ\edital-convocacao-eleicao-de-delegados-voto-eletronico-2019_2022-_1-14295251612792152872.txt
# Normalizando arquivo: data/nlp\SICREDI CEARÁ\edital_ago_sicredi_ceara_2022-1236210203355123993.txt
# Arquivo 'edital_ago_sicredi_ceara_2022-1236210203355123993.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CEARÁ\edital_ago_sicredi_ceara_2022-1236210203355123993.txt
# Normalizando arquivo: data/nlp\SICREDI CEARÁ\edital_pre-assembleia_geral_extraordinaria_digital_da_sicredi_ceara_2022_-_200722.txt
# Arquivo 'edital_pre-assembleia_geral_extraordinaria_digital_da_sicredi_ceara_2022_-_200722.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CEARÁ\edital_pre-assembleia_geral_extraordinaria_digital_da_sicredi_ceara_2022_-_200722.txt
# Normalizando arquivo: data/nlp\SICREDI CEARÁ\edital_sicredi-ce_-_ago_-_12022020_-_delegados.txt
# Arquivo 'edital_sicredi-ce_-_ago_-_12022020_-_delegados.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CEARÁ\edital_sicredi-ce_-_ago_-_12022020_-_delegados.txt
# Normalizando arquivo: data/nlp\SICREDI CEARÁ\edital_sicredi-ce_-_pre-age_-_12022020_-_pas_fortaleza.txt
# Arquivo 'edital_sicredi-ce_-_pre-age_-_12022020_-_pas_fortaleza.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CEARÁ\edital_sicredi-ce_-_pre-age_-_12022020_-_pas_fortaleza.txt
# Normalizando arquivo: data/nlp\SICREDI CEARÁ\edital_sicredi-ce_-_pre-age_-_12022020_-_pas_limoeiromoradanovarussas.txt
# Arquivo 'edital_sicredi-ce_-_pre-age_-_12022020_-_pas_limoeiromoradanovarussas.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CEARÁ\edital_sicredi-ce_-_pre-age_-_12022020_-_pas_limoeiromoradanovarussas.txt
# Normalizando arquivo: data/nlp\SICREDI CEARÁ\edital_sicredi-ce_-_pre-age_-_12022020_-_pas_quixada.txt
# Arquivo 'edital_sicredi-ce_-_pre-age_-_12022020_-_pas_quixada.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CEARÁ\edital_sicredi-ce_-_pre-age_-_12022020_-_pas_quixada.txt
# Normalizando arquivo: data/nlp\SICREDI CEARÁ\edital_sicredi-ce_-_pre-age_-_12022020_-_pa_crateus.txt
# Arquivo 'edital_sicredi-ce_-_pre-age_-_12022020_-_pa_crateus.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CEARÁ\edital_sicredi-ce_-_pre-age_-_12022020_-_pa_crateus.txt
# Normalizando arquivo: data/nlp\SICREDI CEARÁ\edital_sicredi-ce_-_pre-age_-_12022020_-_pa_itapipoca.txt
# Arquivo 'edital_sicredi-ce_-_pre-age_-_12022020_-_pa_itapipoca.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CEARÁ\edital_sicredi-ce_-_pre-age_-_12022020_-_pa_itapipoca.txt
# Normalizando arquivo: data/nlp\SICREDI CEARÁ\edital_sicredi-ce_-_pre-age_-_12022020_-_pa_sobral.txt
# Arquivo 'edital_sicredi-ce_-_pre-age_-_12022020_-_pa_sobral.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CEARÁ\edital_sicredi-ce_-_pre-age_-_12022020_-_pa_sobral.txt
# Normalizando arquivo: data/nlp\SICREDI CEARÁ\edital_sicredi-ce_-_pre-age_-_12022020_-_pa_taua.txt
# Arquivo 'edital_sicredi-ce_-_pre-age_-_12022020_-_pa_taua.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CEARÁ\edital_sicredi-ce_-_pre-age_-_12022020_-_pa_taua.txt
# Normalizando arquivo: data/nlp\SICREDI CEARÁ\edital_sicredi-ce_-_pre-age_-_23092019_-_pas_-_sedepatiodomluishruavstodumont.txt
# Arquivo 'edital_sicredi-ce_-_pre-age_-_23092019_-_pas_-_sedepatiodomluishruavstodumont.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CEARÁ\edital_sicredi-ce_-_pre-age_-_23092019_-_pas_-_sedepatiodomluishruavstodumont.txt
# Normalizando arquivo: data/nlp\SICREDI CEARÁ\edital_sicredi-ce_-_pre-ago_-_12022020_-_pas_fortaleza.txt
# Arquivo 'edital_sicredi-ce_-_pre-ago_-_12022020_-_pas_fortaleza.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CEARÁ\edital_sicredi-ce_-_pre-ago_-_12022020_-_pas_fortaleza.txt
# Normalizando arquivo: data/nlp\SICREDI CEARÁ\edital_sicredi-ce_-_pre-ago_-_12022020_-_pas_limoeiromoradanovarussas.txt
# Arquivo 'edital_sicredi-ce_-_pre-ago_-_12022020_-_pas_limoeiromoradanovarussas.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CEARÁ\edital_sicredi-ce_-_pre-ago_-_12022020_-_pas_limoeiromoradanovarussas.txt
# Normalizando arquivo: data/nlp\SICREDI CEARÁ\edital_sicredi-ce_-_pre-ago_-_12022020_-_pas_quixada.txt
# Arquivo 'edital_sicredi-ce_-_pre-ago_-_12022020_-_pas_quixada.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CEARÁ\edital_sicredi-ce_-_pre-ago_-_12022020_-_pas_quixada.txt
# Normalizando arquivo: data/nlp\SICREDI CEARÁ\edital_sicredi-ce_-_pre-ago_-_12022020_-_pa_crateus.txt
# Arquivo 'edital_sicredi-ce_-_pre-ago_-_12022020_-_pa_crateus.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CEARÁ\edital_sicredi-ce_-_pre-ago_-_12022020_-_pa_crateus.txt
# Normalizando arquivo: data/nlp\SICREDI CEARÁ\edital_sicredi-ce_-_pre-ago_-_12022020_-_pa_itapipoca.txt
# Arquivo 'edital_sicredi-ce_-_pre-ago_-_12022020_-_pa_itapipoca.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CEARÁ\edital_sicredi-ce_-_pre-ago_-_12022020_-_pa_itapipoca.txt
# Normalizando arquivo: data/nlp\SICREDI CEARÁ\edital_sicredi-ce_-_pre-ago_-_12022020_-_pa_sobral.txt
# Arquivo 'edital_sicredi-ce_-_pre-ago_-_12022020_-_pa_sobral.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CEARÁ\edital_sicredi-ce_-_pre-ago_-_12022020_-_pa_sobral.txt
# Normalizando arquivo: data/nlp\SICREDI CEARÁ\edital_sicredi-ce_-_pre-ago_-_12022020_-_pa_taua.txt
# Arquivo 'edital_sicredi-ce_-_pre-ago_-_12022020_-_pa_taua.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CEARÁ\edital_sicredi-ce_-_pre-ago_-_12022020_-_pa_taua.txt
# Normalizando arquivo: data/nlp\SICREDI CEARÁ\edital_sicredi-ce_-_pre-ago_-_24042019_-_pas_-_sedepatiodomluishruavstodumont.txt
# Arquivo 'edital_sicredi-ce_-_pre-ago_-_24042019_-_pas_-_sedepatiodomluishruavstodumont.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CEARÁ\edital_sicredi-ce_-_pre-ago_-_24042019_-_pas_-_sedepatiodomluishruavstodumont.txt
# Normalizando arquivo: data/nlp\SICREDI CEARÁ\estatuto_social_2022.txt
# Arquivo 'estatuto_social_2022.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CEARÁ\estatuto_social_2022.txt
# Normalizando arquivo: data/nlp\SICREDI CEARÁ\estatuto_social_sicredi_ceara_mudancas_2023_atualizado_dia_090223.txt
# Arquivo 'estatuto_social_sicredi_ceara_mudancas_2023_atualizado_dia_090223.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CEARÁ\estatuto_social_sicredi_ceara_mudancas_2023_atualizado_dia_090223.txt
# Normalizando arquivo: data/nlp\SICREDI CEARÁ\guia_do_associado_2023_sicredi_ceara.txt
# Arquivo 'guia_do_associado_2023_sicredi_ceara.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CEARÁ\guia_do_associado_2023_sicredi_ceara.txt
# Normalizando arquivo: data/nlp\SICREDI CEARÁ\novo_edital_da_age_e_ago_sicredi_ceara_2023_delegados_dt_290423_6.txt
# Arquivo 'novo_edital_da_age_e_ago_sicredi_ceara_2023_delegados_dt_290423_6.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CEARÁ\novo_edital_da_age_e_ago_sicredi_ceara_2023_delegados_dt_290423_6.txt
# Normalizando arquivo: data/nlp\SICREDI CEARÁ\relatorio_de_gestao_2021.txt
# Arquivo 'relatorio_de_gestao_2021.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CEARÁ\relatorio_de_gestao_2021.txt
# Normalizando arquivo: data/nlp\SICREDI CEARÁ\tabela_de_tarifas_abril_2023_-_a3.txt
# Arquivo 'tabela_de_tarifas_abril_2023_-_a3.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CEARÁ\tabela_de_tarifas_abril_2023_-_a3.txt
# Normalizando arquivo: data/nlp\SICREDI CREDUNI\assembleia_digital_tutorial_de_acesso_-_assembleias_2022.txt
# Arquivo 'assembleia_digital_tutorial_de_acesso_-_assembleias_2022.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CREDUNI\assembleia_digital_tutorial_de_acesso_-_assembleias_2022.txt
# Normalizando arquivo: data/nlp\SICREDI CREDUNI\assembleia_digital_tutorial_durante_o_evento_-_assembleias_2022.txt
# Arquivo 'assembleia_digital_tutorial_durante_o_evento_-_assembleias_2022.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CREDUNI\assembleia_digital_tutorial_durante_o_evento_-_assembleias_2022.txt
# Normalizando arquivo: data/nlp\SICREDI CREDUNI\divulgacao_candidatos_-_eleicao_de_delegados_2021.txt
# Arquivo 'divulgacao_candidatos_-_eleicao_de_delegados_2021.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CREDUNI\divulgacao_candidatos_-_eleicao_de_delegados_2021.txt
# Normalizando arquivo: data/nlp\SICREDI CREDUNI\edital_convocacao_2021-11050480759621369119.txt
# Arquivo 'edital_convocacao_2021-11050480759621369119.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CREDUNI\edital_convocacao_2021-11050480759621369119.txt
# Normalizando arquivo: data/nlp\SICREDI CREDUNI\edital_convocacao_2022.txt
# Arquivo 'edital_convocacao_2022.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CREDUNI\edital_convocacao_2022.txt
# Normalizando arquivo: data/nlp\SICREDI CREDUNI\edital_de_convocacao_-_ago_2023.txt
# Arquivo 'edital_de_convocacao_-_ago_2023.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CREDUNI\edital_de_convocacao_-_ago_2023.txt
# Normalizando arquivo: data/nlp\SICREDI CREDUNI\edital_de_convocacao_da_age_2022_v2.txt
# Arquivo 'edital_de_convocacao_da_age_2022_v2.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CREDUNI\edital_de_convocacao_da_age_2022_v2.txt
# Normalizando arquivo: data/nlp\SICREDI CREDUNI\inscricao_conselho_fiscal_2022.txt
# Arquivo 'inscricao_conselho_fiscal_2022.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CREDUNI\inscricao_conselho_fiscal_2022.txt
# Normalizando arquivo: data/nlp\SICREDI CREDUNI\parecer_ernest_young_2021.txt
# Arquivo 'parecer_ernest_young_2021.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CREDUNI\parecer_ernest_young_2021.txt
# Normalizando arquivo: data/nlp\SICREDI CREDUNI\relatorio_anual_2021_-.txt
# Arquivo 'relatorio_anual_2021_-.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CREDUNI\relatorio_anual_2021_-.txt
# Normalizando arquivo: data/nlp\SICREDI CREDUNI\relatorio_anual_2022.txt
# Arquivo 'relatorio_anual_2022.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CREDUNI\relatorio_anual_2022.txt
# Normalizando arquivo: data/nlp\SICREDI CREDUNI\sicredi_creduni_122021.txt
# Arquivo 'sicredi_creduni_122021.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CREDUNI\sicredi_creduni_122021.txt
# Normalizando arquivo: data/nlp\SICREDI CREDUNI\termo_de_inscricao_de_chapa_2022.txt
# Arquivo 'termo_de_inscricao_de_chapa_2022.txt' normalizado e salvo em: data/nlp_normalized\SICREDI CREDUNI\termo_de_inscricao_de_chapa_2022.txt
# Normalizando arquivo: data/nlp\SICREDI INTEGRAÇÃO DE ESTADOS RS_SC\demonstracoes_financeiras_2020.txt
# Arquivo 'demonstracoes_financeiras_2020.txt' normalizado e salvo em: data/nlp_normalized\SICREDI INTEGRAÇÃO DE ESTADOS RS_SC\demonstracoes_financeiras_2020.txt
# Normalizando arquivo: data/nlp\SICREDI INTEGRAÇÃO DE ESTADOS RS_SC\demonstracoes_financeiras__sicredi_integracao_de_estados_rs_sc_122021.txt
# Arquivo 'demonstracoes_financeiras__sicredi_integracao_de_estados_rs_sc_122021.txt' normalizado e salvo em: data/nlp_normalized\SICREDI INTEGRAÇÃO DE ESTADOS RS_SC\demonstracoes_financeiras__sicredi_integracao_de_estados_rs_sc_122021.txt
# Normalizando arquivo: data/nlp\SICREDI INTEGRAÇÃO DE ESTADOS RS_SC\edital_age_-_0228.txt
# Arquivo 'edital_age_-_0228.txt' normalizado e salvo em: data/nlp_normalized\SICREDI INTEGRAÇÃO DE ESTADOS RS_SC\edital_age_-_0228.txt
# Normalizando arquivo: data/nlp\SICREDI RECIFE\ag2203_122020.txt
# Arquivo 'ag2203_122020.txt' normalizado e salvo em: data/nlp_normalized\SICREDI RECIFE\ag2203_122020.txt
# Normalizando arquivo: data/nlp\SICREDI RECIFE\balanco_patrimonial_2022_x_2023.txt
# Arquivo 'balanco_patrimonial_2022_x_2023.txt' normalizado e salvo em: data/nlp_normalized\SICREDI RECIFE\balanco_patrimonial_2022_x_2023.txt
# Normalizando arquivo: data/nlp\SICREDI RECIFE\demonstracoes_financeiras_2022_atualizado.txt
# Arquivo 'demonstracoes_financeiras_2022_atualizado.txt' normalizado e salvo em: data/nlp_normalized\SICREDI RECIFE\demonstracoes_financeiras_2022_atualizado.txt
# Normalizando arquivo: data/nlp\SICREDI RECIFE\estatuto_social_sicredi_recife_vfinal_2301.txt
# Arquivo 'estatuto_social_sicredi_recife_vfinal_2301.txt' normalizado e salvo em: data/nlp_normalized\SICREDI RECIFE\estatuto_social_sicredi_recife_vfinal_2301.txt
# Normalizando arquivo: data/nlp\SICREDI RECIFE\parecer_da_auditoria_independente_sobre_as_demonstracoes_financeiras_de_2020.txt
# Arquivo 'parecer_da_auditoria_independente_sobre_as_demonstracoes_financeiras_de_2020.txt' normalizado e salvo em: data/nlp_normalized\SICREDI RECIFE\parecer_da_auditoria_independente_sobre_as_demonstracoes_financeiras_de_2020.txt
# Normalizando arquivo: data/nlp\SICREDI RECIFE\parecer_do_conselho_fiscal_2020.txt
# Arquivo 'parecer_do_conselho_fiscal_2020.txt' normalizado e salvo em: data/nlp_normalized\SICREDI RECIFE\parecer_do_conselho_fiscal_2020.txt
# Normalizando arquivo: data/nlp\SICREDI RECIFE\relatorio_de_auditoria_coop_2203.txt
# Arquivo 'relatorio_de_auditoria_coop_2203.txt' normalizado e salvo em: data/nlp_normalized\SICREDI RECIFE\relatorio_de_auditoria_coop_2203.txt
# Normalizando arquivo: data/nlp\SICREDI RECIFE\relatorio_sicredi_recife_2021_compressed.txt
# Arquivo 'relatorio_sicredi_recife_2021_compressed.txt' normalizado e salvo em: data/nlp_normalized\SICREDI RECIFE\relatorio_sicredi_recife_2021_compressed.txt
# Normalizando arquivo: data/nlp\SICREDI RECIFE\sicredi_recife_-_edital_age_07fev2023.txt
# Arquivo 'sicredi_recife_-_edital_age_07fev2023.txt' normalizado e salvo em: data/nlp_normalized\SICREDI RECIFE\sicredi_recife_-_edital_age_07fev2023.txt
# Normalizando arquivo: data/nlp\SICREDI RECIFE\tabela_de_tarifas_-_cheque_especial_2023.txt
# Arquivo 'tabela_de_tarifas_-_cheque_especial_2023.txt' normalizado e salvo em: data/nlp_normalized\SICREDI RECIFE\tabela_de_tarifas_-_cheque_especial_2023.txt

# %%
pip install mtranslate
# Out:
# Collecting mtranslate
#   Downloading mtranslate-1.8.tar.gz (2.4 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: mtranslate
#   Building wheel for mtranslate (setup.py): started
#   Building wheel for mtranslate (setup.py): finished with status 'done'
#   Created wheel for mtranslate: filename=mtranslate-1.8-py3-none-any.whl size=3680 sha256=fbbcc15cc586c531e3d06d6c3bab4b505f32a186bf12a9058efa8e40aadae35f
#   Stored in directory: c:\users\mjzag\appdata\local\pip\cache\wheels\38\00\7c\b947c5efaf4ddcf011a91b1566f80851ea560351fd81d029ef
# Successfully built mtranslate
# Installing collected packages: mtranslate
# Successfully installed mtranslate-1.8
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from textwrap import wrap
from mtranslate import translate

# Diretórios de entrada e saída
diretorio_entrada = 'data/nlp_normalized'
diretorio_saida_ingles = 'data/nlp_normalized_english'

# Percorrer os arquivos de texto no diretório de entrada
for pasta_raiz, _, arquivos in os.walk(diretorio_entrada):
    for arquivo in arquivos:
        if arquivo.endswith('.txt'):
            caminho_completo_entrada = os.path.join(pasta_raiz, arquivo)
            caminho_completo_saida = os.path.join(pasta_raiz.replace(diretorio_entrada, diretorio_saida_ingles), arquivo)

            # Verificar se o arquivo já foi traduzido
            if os.path.exists(caminho_completo_saida):
                print(f"O arquivo '{arquivo}' já foi traduzido. Indo para o próximo arquivo.")
                continue

            print(f"Traduzindo arquivo: {caminho_completo_entrada}")

            # Ler o conteúdo do arquivo de entrada
            with open(caminho_completo_entrada, 'r', encoding='utf-8') as arquivo_entrada:
                texto = arquivo_entrada.read()

            # Dividir o texto em chunks menores
            chunks_texto = wrap(texto, width=500)

            # Traduzir cada chunk e combinar as traduções
            chunks_traduzidos = []
            for chunk in chunks_texto:
                chunk_traduzido = translate(chunk, 'en', 'auto')
                chunks_traduzidos.append(chunk_traduzido)

            texto_traduzido = ' '.join(chunks_traduzidos)

            # Criar diretório de saída se não existir
            os.makedirs(os.path.dirname(caminho_completo_saida), exist_ok=True)

            # Escrever o texto traduzido no arquivo de saída
            with open(caminho_completo_saida, 'w', encoding='utf-8') as arquivo_saida:
                arquivo_saida.write(texto_traduzido)

            print(f"Arquivo '{arquivo}' traduzido e salvo em: {caminho_completo_saida}")
# Out:
# Traduzindo arquivo: data/nlp_normalized\CC SICREDI COOMAMP\ago-age_de_04042023_-_sicredi_coomamp.txt
# Arquivo 'ago-age_de_04042023_-_sicredi_coomamp.txt' traduzido e salvo em: data/nlp_normalized_english\CC SICREDI COOMAMP\ago-age_de_04042023_-_sicredi_coomamp.txt
# Traduzindo arquivo: data/nlp_normalized\CC SICREDI COOMAMP\ata_age_digital_2020-10906245163955933242.txt
# Arquivo 'ata_age_digital_2020-10906245163955933242.txt' traduzido e salvo em: data/nlp_normalized_english\CC SICREDI COOMAMP\ata_age_digital_2020-10906245163955933242.txt
# Traduzindo arquivo: data/nlp_normalized\CC SICREDI COOMAMP\ata_ago-age_2020_-_sicredi_coomamp-14269571789062083743.txt
# Arquivo 'ata_ago-age_2020_-_sicredi_coomamp-14269571789062083743.txt' traduzido e salvo em: data/nlp_normalized_english\CC SICREDI COOMAMP\ata_ago-age_2020_-_sicredi_coomamp-14269571789062083743.txt
# Traduzindo arquivo: data/nlp_normalized\CC SICREDI COOMAMP\ata_agoage_2022_-_sicredi_coomamp.txt
# Arquivo 'ata_agoage_2022_-_sicredi_coomamp.txt' traduzido e salvo em: data/nlp_normalized_english\CC SICREDI COOMAMP\ata_agoage_2022_-_sicredi_coomamp.txt
# Traduzindo arquivo: data/nlp_normalized\CC SICREDI COOMAMP\ata_ago_age_2018-5498222428478009411.txt
# Arquivo 'ata_ago_age_2018-5498222428478009411.txt' traduzido e salvo em: data/nlp_normalized_english\CC SICREDI COOMAMP\ata_ago_age_2018-5498222428478009411.txt
# Traduzindo arquivo: data/nlp_normalized\CC SICREDI COOMAMP\ata_de_homologacao-2409316498742798561.txt
# Arquivo 'ata_de_homologacao-2409316498742798561.txt' traduzido e salvo em: data/nlp_normalized_english\CC SICREDI COOMAMP\ata_de_homologacao-2409316498742798561.txt
# Traduzindo arquivo: data/nlp_normalized\CC SICREDI COOMAMP\chapas_inscritas-7992939441822030231.txt
# Arquivo 'chapas_inscritas-7992939441822030231.txt' traduzido e salvo em: data/nlp_normalized_english\CC SICREDI COOMAMP\chapas_inscritas-7992939441822030231.txt
# Traduzindo arquivo: data/nlp_normalized\CC SICREDI COOMAMP\edital-de-convocacao-ago-age-2020-9922671639141617290.txt
# Arquivo 'edital-de-convocacao-ago-age-2020-9922671639141617290.txt' traduzido e salvo em: data/nlp_normalized_english\CC SICREDI COOMAMP\edital-de-convocacao-ago-age-2020-9922671639141617290.txt
# Traduzindo arquivo: data/nlp_normalized\CC SICREDI COOMAMP\edital_age__presencial_maio2023.txt
# Arquivo 'edital_age__presencial_maio2023.txt' traduzido e salvo em: data/nlp_normalized_english\CC SICREDI COOMAMP\edital_age__presencial_maio2023.txt
# Traduzindo arquivo: data/nlp_normalized\CC SICREDI COOMAMP\edital_ago-age_-_2022-5192814098258424985.txt
# Arquivo 'edital_ago-age_-_2022-5192814098258424985.txt' traduzido e salvo em: data/nlp_normalized_english\CC SICREDI COOMAMP\edital_ago-age_-_2022-5192814098258424985.txt
# Traduzindo arquivo: data/nlp_normalized\CC SICREDI COOMAMP\edital_agoage__virtual_2023.txt
# Arquivo 'edital_agoage__virtual_2023.txt' traduzido e salvo em: data/nlp_normalized_english\CC SICREDI COOMAMP\edital_agoage__virtual_2023.txt
# Traduzindo arquivo: data/nlp_normalized\CC SICREDI COOMAMP\edital_ago_-_age_-_sicredi_coomamp_-_2021-3606688643084409760.txt
# Arquivo 'edital_ago_-_age_-_sicredi_coomamp_-_2021-3606688643084409760.txt' traduzido e salvo em: data/nlp_normalized_english\CC SICREDI COOMAMP\edital_ago_-_age_-_sicredi_coomamp_-_2021-3606688643084409760.txt
# Traduzindo arquivo: data/nlp_normalized\CC SICREDI COOMAMP\inf901005545390122022_2002-manifesto.txt
# Arquivo 'inf901005545390122022_2002-manifesto.txt' traduzido e salvo em: data/nlp_normalized_english\CC SICREDI COOMAMP\inf901005545390122022_2002-manifesto.txt
# Traduzindo arquivo: data/nlp_normalized\CC SICREDI COOMAMP\relatorio_2021_-_sicredi_coomamp-7845100396790685305.txt
# Arquivo 'relatorio_2021_-_sicredi_coomamp-7845100396790685305.txt' traduzido e salvo em: data/nlp_normalized_english\CC SICREDI COOMAMP\relatorio_2021_-_sicredi_coomamp-7845100396790685305.txt
# Traduzindo arquivo: data/nlp_normalized\CC SICREDI COOMAMP\relatorio_sicredi_coomamp_-2022.txt
# Arquivo 'relatorio_sicredi_coomamp_-2022.txt' traduzido e salvo em: data/nlp_normalized_english\CC SICREDI COOMAMP\relatorio_sicredi_coomamp_-2022.txt
# Traduzindo arquivo: data/nlp_normalized\CC SICREDI COOMAMP\sicredi_coomamp_122021-15867711859122017097.txt
